# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2023-09_pms3003.csv', sep=';')

# %%
df
# Out:
#         sensor_id sensor_type  location        lat        lon  \
# 0           76635     PMS3003     65531  54.952455  73.383580
# 1           74063     PMS3003     62420  54.990236  73.403946
# 2           44933     PMS3003     30667  43.614000   1.442000
# 3           50359     PMS3003     62159  54.950519  73.172065
# 4           65556     PMS3003     52200  53.490000  14.376000
# ...           ...         ...       ...        ...        ...
# 108982      71461     PMS3003     59265  52.419136  -1.774643
# 108983      12542     PMS3003      6337  49.556000  25.594000
# 108984      44933     PMS3003     30667  43.614000   1.442000
# 108985      50359     PMS3003     62159  54.950519  73.172065
# 108986      65556     PMS3003     52200  53.490000  14.376000
#
#                   timestamp     P1     P2    P0
# 0       2023-09-01T00:00:20  11.33  10.33  8.00
# 1       2023-09-01T00:00:30   6.25   3.25  2.00
# 2       2023-09-01T00:00:32   7.80   6.00  2.40
# ...

# %%
##showing all lat and lon in the ukraine
filt = (df['lat'] > 46.200000) & (df['lat'] < 51.560000) & (df['lon'] > 24.140000) & (df['lon'] < 40.000000)
df.loc[filt]
# Out:
#         sensor_id sensor_type  location     lat     lon            timestamp  \
# 5           12542     PMS3003      6337  49.556  25.594  2023-09-01T00:00:59
# 10          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:03:28
# 18          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:05:55
# 25          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:08:31
# 32          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:10:58
# ...           ...         ...       ...     ...     ...                  ...
# 108959      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:48:37
# 108964      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:51:08
# 108970      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:53:35
# 108976      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:56:03
# 108983      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:58:36
#
#            P1    P2  P0
# ...

# %%
##SHOWING TO HIGH AIR QUALITY
filt_P2 = (df['P2'] > 25,0)
filt_P2
# Out:
# (0         False
#  1         False
#  2         False
#  3         False
#  4         False
#            ...
#  108982    False
#  108983    False
#  108984    False
#  108985    False
#  108986    False
#  Name: P2, Length: 108987, dtype: bool,
#  0)

# %%
##SHOWING TO HIGH AIR QUALITY
filt_P1 = (df['P1'] > 40,0)
filt_P1
# Out:
# (0         False
#  1         False
#  2         False
#  3         False
#  4         False
#            ...
#  108982    False
#  108983    False
#  108984    False
#  108985    False
#  108986    False
#  Name: P1, Length: 108987, dtype: bool,
#  0)

# %%
filt_P1[True]
# Out:
# 0

# %%
filt_P2[True]
# Out:
# 0

# %%
df.loc[filt].describe
# Out:
# <bound method NDFrame.describe of         sensor_id sensor_type  location     lat     lon            timestamp  \
# 5           12542     PMS3003      6337  49.556  25.594  2023-09-01T00:00:59
# 10          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:03:28
# 18          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:05:55
# 25          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:08:31
# 32          12542     PMS3003      6337  49.556  25.594  2023-09-01T00:10:58
# ...           ...         ...       ...     ...     ...                  ...
# 108959      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:48:37
# 108964      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:51:08
# 108970      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:53:35
# 108976      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:56:03
# 108983      12542     PMS3003      6337  49.556  25.594  2023-09-30T23:58:36
#
# ...

# %%
sns.boxplot(df['P1'])
# Out:
# <Axes: >
